# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/Users/Apple/Desktop/Hubspot/data/processed/nps.csv")

# %%
df.head()
# Out:
#    response_id    date  score taxonomy_type  \
# 0    175242837  2/4/26      7           NaN
# 1    175220830  2/4/26      0           NaN
# 2    175230286  2/4/26     10           NaN
# 3    175219745  2/4/26      6           NaN
# 4    175222744  2/4/26      6           NaN
#
#                                        response_text translated_text  \
# 0  Seems to be an excessive amount of repeating s...             NaN
# 1                                              price             NaN
# 2                                         it's handy             NaN
# 3                              æŽ¥ç¶šé€Ÿåº¦ãŒé…ã„             NaN
# 4  Still find it hard to get it to do what I want...             NaN
#
#           page_url
# 0   Dashboard Page
# 1   Dashboard Page
# 2   Dashboard Page
# 3   Dashboard Page
# 4  Globalhome Page

# %%
df.tail()
# Out:
#        response_id    date  score  taxonomy_type  \
# 11435    152925378  1/2/25      6  Functionality
# 11436    152935346  1/2/25      1      Usability
# 11437    152861993  1/1/25      9      Usability
# 11438    152891497  1/1/25      6        General
# 11439    152862994  1/1/25     10      Usability
#
#                                            response_text  \
# 11435  Es hat viel Potential aber es fehlt an Ressour...
# 11436  Confusing and difficult to use. Bullhorn was s...
# 11437                      I like how its user friendly.
# 11438                                         Muito caro
# 11439  Everything seems pretty easy, and UI is also u...
#
#                                          translated_text        page_url
# 11435  It has a lot of potential, but there is a lack...  Dashboard Page
# 11436                                               none  Dashboard Page
# 11437                                               none  Dashboard Page
# 11438                                     Very expensive  Dashboard Page
# 11439                                               none  Dashboard Page

# %%
df.info()
'''# Column Type Notes

Numerical: score
Numerical (identifier — treat as categorical): response_id
Categorical: taxonomy_type, page_url
Text (qualitative / NLP): response_text, translated_text
Date (convert from string): date '''
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11440 entries, 0 to 11439
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   response_id      11440 non-null  int64
#  1   date             11440 non-null  object
#  2   score            11440 non-null  int64
#  3   taxonomy_type    11401 non-null  object
#  4   response_text    11366 non-null  object
#  5   translated_text  11399 non-null  object
#  6   page_url         11440 non-null  object
# dtypes: int64(2), object(5)
# memory usage: 625.8+ KB
# '# Column Type Notes\n\nNumerical: score\nNumerical (identifier — treat as categorical): response_id\nCategorical: taxonomy_type, page_url\nText (qualitative / NLP): response_text, translated_text\nDate (convert from string): date '

# %%
'''Data overview'''

print("=" * 40)
print("DATA OVERVIEW")
print("=" * 40)
print(f"Total Records:      {len(df)}")
print(f"Number of Features: {df.shape[1]}")
print(f"Columns:            {list(df.columns)}")

date_cols = df.columns[df.columns.str.contains('date', case=False)]
print(f"Date Range:         {df[date_cols].min().values[0]} – {df[date_cols].max().values[0]}")
# Out:
# ========================================
# DATA OVERVIEW
# ========================================
# Total Records:      11440
# Number of Features: 7
# Columns:            ['response_id', 'date', 'score', 'taxonomy_type', 'response_text', 'translated_text', 'page_url']
# Date Range:         1/1/25 – 9/9/25

# %%
'''Score Column'''

score_col = [c for c in df.columns if 'score' in c.lower() or 'nps' in c.lower() or 'rating' in c.lower()]
print(f"Detected score column(s): {score_col}")
print(">>> If wrong, change 'score_col' below manually <<<")

score_col = score_col[0] if score_col else df.columns[0]
print(f"\nUsing: '{score_col}'")
# Out:
# Detected score column(s): ['score']
# >>> If wrong, change 'score_col' below manually <<<
#
# Using: 'score'

# %%
'''Score Distributon'''

promoters  = df[df[score_col] >= 9]
passives   = df[(df[score_col] >= 7) & (df[score_col] <= 8)]
detractors = df[df[score_col] <= 6]

total    = len(df)
prom_pct = len(promoters)  / total * 100
pass_pct = len(passives)   / total * 100
det_pct  = len(detractors) / total * 100
nps      = prom_pct - det_pct

print("=" * 40)
print("SCORE DISTRIBUTION")
print("=" * 40)
print(f"Promoters (9-10):   {len(promoters):>6}  ({prom_pct:.1f}%)")
print(f"Passives (7-8):     {len(passives):>6}  ({pass_pct:.1f}%)")
print(f"Detractors (0-6):   {len(detractors):>6}  ({det_pct:.1f}%)")
print(f"\nOverall NPS:        {nps:.1f}")
# Out:
# ========================================
# SCORE DISTRIBUTION
# ========================================
# Promoters (9-10):     4882  (42.7%)
# Passives (7-8):       2023  (17.7%)
# Detractors (0-6):     4535  (39.6%)
#
# Overall NPS:        3.0

# %%
'''Descriptive Statistics'''

print("=" * 40)
print("DESCRIPTIVE STATISTICS")
print("=" * 40)
print(f"Mean:               {df[score_col].mean():.2f}")
print(f"Median:             {df[score_col].median():.2f}")
print(f"Std. Deviation:     {df[score_col].std():.2f}")
print(f"Min / Max:          {df[score_col].min()} / {df[score_col].max()}")
# Out:
# ========================================
# DESCRIPTIVE STATISTICS
# ========================================
# Mean:               6.58
# Median:             8.00
# Std. Deviation:     3.57
# Min / Max:          0 / 10
